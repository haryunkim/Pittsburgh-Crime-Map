# %% [markdown]
# # Pittsburgh Crime Dataset Exploration

# %% [markdown]
# ## Import Libraries

# %%
import re
import unicodedata
import pandas as pd
import folium

# %% [markdown]
# ## Load and Inspect Data

# %%
df = pd.read_excel("../data/raw/crime_jan1_oct31_2025.xlsx", engine="openpyxl")
df.head()
# Out:
#   Report_Number ReportedDate ReportedTime  Hour DayofWeek ReportedMonth  \
# 0  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 1  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 2  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 3  PGHP24000024   2024-01-01        00:31     0    Monday           Jan
# 4  PGHP24000017   2024-01-01        00:21     0    Monday           Jan
#
#                            NIBRS_Coded_Offense NIBRS_Offense_Code  \
# 0                       13A AGGRAVATED ASSAULT                13A
# 1                             13C INTIMIDATION                13C
# 2                       90Z ALL OTHER OFFENSES                90Z
# 3                        23H ALL OTHER LARCENY                23H
# 4  9999 Vehicle Offense (Not NIBRS Reportable)                999
#
#    NIBRS_Offense_Category    NIBRS_Offense_Type NIBRS_Crime_Against  \
# 0        Assault Offenses    Aggravated Assault              Person
# 1        Assault Offenses          Intimidation              Person
# 2      All other Offenses    All other Offenses             Group B
# 3  Larceny/Theft Offenses     All Other Larceny            Property
# 4    Not NIBRS Reportable  Not NIBRS Reportable             Group B
#
#   NIBRS_Offense_Grouping                                          Violation  \
# 0                      A          18 2718 A1 Strangulation Basic - Applying
# 1                      A             18 2706 A1 Terroristic Threats-General
# 2                      B  75 3733 A Fleeing or Attempting To Elude Polic...
# 3                      A  18 3921 A Theft by Unlawful Taking-Movable – L...
# 4                      B          LO 6 101 Discharge of Firearms Prohibited
#
#     XCOORD   YCOORD    Zone Tract Neighborhood  \
# 0 -80.0268  40.3964  Zone 6  1919    Brookline
# 1 -80.0268  40.3964  Zone 6  1919    Brookline
# 2 -80.0268  40.3964  Zone 6  1919    Brookline
# 3 -80.0268  40.3964  Zone 6  1919    Brookline
# 4 -80.0243  40.4582  Zone 1  2107   Manchester
#
#                                 Block_Address
# 0  2800 Block of  FITZHUGH WAY Pittsburgh, PA
# 1  2800 Block of  FITZHUGH WAY Pittsburgh, PA
# 2  2800 Block of  FITZHUGH WAY Pittsburgh, PA
# 3  2800 Block of  FITZHUGH WAY Pittsburgh, PA
# 4  1200 Block of  COLUMBUS AVE Pittsburgh, PA

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Convert ReportedDate to datetime

# %%
df['ReportedDate'] = pd.to_datetime(df['ReportedDate'], errors='coerce')
df = df[df["ReportedDate"].notna()]

# %% [markdown]
# ### Extract Year, Month

# %%
df['Year'] = df['ReportedDate'].dt.year
df['Month'] = df['ReportedDate'].dt.month
df['MonthName'] = df['ReportedDate'].dt.strftime("%b")

# %% [markdown]
# ### Clean neighborhood

# %%
NEIGHBORHOOD_NORMALIZATION_MAP = {
    "spring hill city view": "Spring Hill-City View",
    "spring hill-city view": "Spring Hill-City View",
    "spring hill–city view": "Spring Hill-City View",
    "spring hill—city view": "Spring Hill-City View",

    "lincoln lemington belmar": "Lincoln-Lemington-Belmar",
    "lincoln-lemington-belmar": "Lincoln-Lemington-Belmar",
    "lincoln–lemington–belmar": "Lincoln-Lemington-Belmar",
    "lincoln—lemington—belmar": "Lincoln-Lemington-Belmar",
}

def clean_neighborhood(name):
    if not isinstance(name, str):
        return name

   
    n = unicodedata.normalize("NFKC", name).strip()

    
    n = re.sub(r"[\u2012\u2013\u2014\u2015]", "-", n)

    
    n = re.sub(r"\s*-\s*", "-", n)

    key = n.lower()

  
    if key in NEIGHBORHOOD_NORMALIZATION_MAP:
        return NEIGHBORHOOD_NORMALIZATION_MAP[key]

   
    return " ".join(word.capitalize() for word in n.split())

# %%
df["Neighborhood"] = df["Neighborhood"].fillna("Unknown")
df["Neighborhood"] = df["Neighborhood"].apply(clean_neighborhood)

# %% [markdown]
# ### X and Y COORD

# %%
df["XCOORD"] = pd.to_numeric(df.get("XCOORD"), errors="coerce")
df["YCOORD"] = pd.to_numeric(df.get("YCOORD"), errors="coerce")
df[['YCOORD', 'XCOORD']].isna().sum()
# Out:
# YCOORD    632
# XCOORD    645
# dtype: int64

# %%
bad_rows = df[df['YCOORD'].isna() | df['XCOORD'].isna()]
bad_rows.head()
# Out:
#     Report_Number ReportedDate ReportedTime  Hour  DayofWeek ReportedMonth  \
# 88   PGHP24000485   2024-01-01        21:48    21     Monday           Jan
# 105  PGHP24000489   2024-01-01        22:14    22     Monday           Jan
# 185  PGHP23169569   2024-01-02        21:00    21    Tuesday           Jan
# 215  PGHP24001063   2024-01-03        08:29     8  Wednesday           Jan
# 304  PGHP24001372   2024-01-03        18:34    18  Wednesday           Jan
#
#                    NIBRS_Coded_Offense NIBRS_Offense_Code  \
# 88                 11B FORCIBLE SODOMY                11B
# 105  11C SEXUAL ASSAULT WITH AN OBJECT                11C
# 185                  11A FORCIBLE RAPE                11A
# 215                 36B STATUTORY RAPE                36B
# 304                 36B STATUTORY RAPE                36B
#
#     NIBRS_Offense_Category             NIBRS_Offense_Type  ...  \
# 88            Sex Offenses                Forcible Sodomy  ...
# 105           Sex Offenses  Sexual Assault With An Object  ...
# 185           Sex Offenses                  Forcible Rape  ...
# 215           Sex Offenses                 Statutory Rape  ...
# 304           Sex Offenses                 Statutory Rape  ...
#
#                                              Violation XCOORD YCOORD    Zone  \
# 88   18 3121 A1 Rape-Forcible Compulsion - Forcible...    NaN    NaN  Zone 6
# 105  18 3123 A3 IDSI-Unconscious Victim - Sexual As...    NaN    NaN  Zone 4
# 185        18 3124.1 Sexual Assault-Sex Offenses, Rape    NaN    NaN  Zone 3
# 215                 18 3122.1 Statutory Sexual Assault    NaN    NaN  Zone 5
# 304                 18 3122.1 Statutory Sexual Assault    NaN    NaN  Zone 5
#
#      Tract Neighborhood Block_Address  Year Month  MonthName
# 88     NaN      Unknown           NaN  2024     1        Jan
# 105    NaN      Unknown           NaN  2024     1        Jan
# 185    NaN      Unknown           NaN  2024     1        Jan
# 215    NaN      Unknown           NaN  2024     1        Jan
# 304    NaN      Unknown           NaN  2024     1        Jan
#
# [5 rows x 22 columns]

# %%
df = df.dropna(subset=['YCOORD', 'XCOORD'])
df[['YCOORD', 'XCOORD']].isna().sum()
# Out:
# YCOORD    0
# XCOORD    0
# dtype: int64

# %% [markdown]
# ### NIBRS_Offense_Category

# %%
categories = df['NIBRS_Offense_Category'].dropna().unique()
categories
# Out:
# array(['Assault Offenses', 'All other Offenses', 'Larceny/Theft Offenses',
#        'Not NIBRS Reportable', 'Destruction/Damage/Vandalism of Property',
#        'Fraud Offenses', 'Weapon Law Violations',
#        'Drug/Narcotic Offenses', 'Robbery', 'Motor Vehicle Theft',
#        'Burglary/Breaking & Entering', 'Arson', 'Human Trafficking',
#        'Kidnapping/Abduction', 'Homicide Offenses'], dtype=object)

# %% [markdown]
# ### NIBRS_Offense_Type

# %%
types = df['NIBRS_Offense_Type'].dropna().unique()
types
# Out:
# array(['Aggravated Assault', 'Intimidation', 'All other Offenses',
#        'All Other Larceny', 'Not NIBRS Reportable', 'Theft from Building',
#        'Drunkenness', 'Disorderly Conduct', 'Trespass of Real Property',
#        'Simple Assault', 'Destruction/Damage/Vandalism of Property',
#        'Shoplifting', 'Credit Card/ATM Fraud',
#        'Theft of Motor Vehicle Parts or Accessories',
#        'False Pretenses/Swindle/Confidence Game', 'Weapon Law Violations',
#        'Pocket-Picking', 'Drug Equipment Violations',
#        'Stolen Property Offenses', 'Drug/Narcotic Violations', 'Robbery',
#        'Motor Vehicle Theft', 'Burglary/Breaking & Entering',
#        'Driving Under the Influence', 'Theft from Motor Vehicle',
#        'Impersonation', 'Bad Checks', 'Counterfeiting/Forgery',
#        'Assisting or Promoting Prostitution', 'Arson',
#        'Family Offenses, Nonviolent', 'Pornography/Obscene Material',
#        'Curfew/Loiting/Vagrancy Violations', 'Purse-snatching',
#        'Involuntary Servitude', 'Kidnapping/Abduction',
#        'Murder & Nonnegligent Manslaughter', 'Hacking/Computer Invasion',
#        'Extortion/Blackmail', 'Embezzlement', 'Liquor Law Violaitons',
#        'Peeping Tom', 'Theft from Coin-operated Machine or Device',
#        'Negligent Manslaughter', 'Prostitution', 'Commercial Sex Acts',
#        'Welfare Fraud', 'Bribery'], dtype=object)

# %% [markdown]
# ### NIBRS Offense Occurences

# %%
df['NIBRS_Offense_Category'].value_counts()
df['NIBRS_Offense_Type'].value_counts()
# Out:
# NIBRS_Offense_Type
# Not NIBRS Reportable                           13080
# Destruction/Damage/Vandalism of Property        5874
# Simple Assault                                  5651
# Intimidation                                    4382
# Drug/Narcotic Violations                        3898
# All other Offenses                              3789
# Disorderly Conduct                              3645
# All Other Larceny                               3153
# Theft from Building                             3103
# Shoplifting                                     3102
# Theft from Motor Vehicle                        2389
# Drug Equipment Violations                       2293
# Motor Vehicle Theft                             2182
# Aggravated Assault                              1717
# Trespass of Real Property                       1672
# Burglary/Breaking & Entering                    1620
# Credit Card/ATM Fraud                           1536
# Weapon Law Violations                           1444
# False Pretenses/Swindle/Confidence Game         1042
# Theft of Motor Vehicle Parts or Accessories      980
# Impersonation                                    897
# Robbery                                          835
# Driving Under the Influence                      810
# Drunkenness                                      628
# Stolen Property Offenses                         558
# Family Offenses, Nonviolent                      322
# Counterfeiting/Forgery                           306
# Arson                                            210
# Curfew/Loiting/Vagrancy Violations               181
# Kidnapping/Abduction                             168
# Extortion/Blackmail                              102
# Bad Checks                                        84
# Purse-snatching                                   68
# Murder & Nonnegligent Manslaughter                63
# Pornography/Obscene Material                      57
# Pocket-Picking                                    45
# Assisting or Promoting Prostitution               33
# Hacking/Computer Invasion                         30
# Liquor Law Violaitons                             29
# Prostitution                                      25
# Theft from Coin-operated Machine or Device        23
# Peeping Tom                                       11
# Embezzlement                                       9
# Negligent Manslaughter                             8
# Commercial Sex Acts                                7
# Involuntary Servitude                              2
# Welfare Fraud                                      1
# Bribery                                            1
# Name: count, dtype: int64

# %% [markdown]
# ### Crime Counts per category

# %%
category_counts = (
    df.groupby('NIBRS_Offense_Category')
      .size()
      .reset_index(name='Count')
      .sort_values('Count', ascending=False)
)
category_counts
# Out:
#                       NIBRS_Offense_Category  Count
# 10                    Larceny/Theft Offenses  13421
# 12                      Not NIBRS Reportable  13080
# 2                           Assault Offenses  11750
# 0                         All other Offenses  11286
# 5                     Drug/Narcotic Offenses   6191
# 4   Destruction/Damage/Vandalism of Property   5874
# 6                             Fraud Offenses   3924
# 11                       Motor Vehicle Theft   2182
# 3               Burglary/Breaking & Entering   1620
# 14                     Weapon Law Violations   1444
# 13                                   Robbery    835
# 1                                      Arson    210
# 9                       Kidnapping/Abduction    168
# 7                          Homicide Offenses     71
# 8                          Human Trafficking      9

# %% [markdown]
# ### Crime types within each category

# %%
type_counts = (
    df.groupby(['NIBRS_Offense_Category', 'NIBRS_Offense_Type'])
      .size()
      .reset_index(name='Count')
      .sort_values('Count', ascending=False)
)
type_counts.head(10)
# Out:
#                       NIBRS_Offense_Category  \
# 45                      Not NIBRS Reportable
# 18  Destruction/Damage/Vandalism of Property
# 16                          Assault Offenses
# 15                          Assault Offenses
# 20                    Drug/Narcotic Offenses
# 0                         All other Offenses
# 4                         All other Offenses
# 35                    Larceny/Theft Offenses
# 40                    Larceny/Theft Offenses
# 38                    Larceny/Theft Offenses
#
#                           NIBRS_Offense_Type  Count
# 45                      Not NIBRS Reportable  13080
# 18  Destruction/Damage/Vandalism of Property   5874
# 16                            Simple Assault   5651
# 15                              Intimidation   4382
# 20                  Drug/Narcotic Violations   3898
# 0                         All other Offenses   3789
# 4                         Disorderly Conduct   3645
# 35                         All Other Larceny   3153
# 40                       Theft from Building   3103
# 38                               Shoplifting   3102

# %%
m = folium.Map(location=[40.44, -79.99], zoom_start=12)
for _, row in df.sample(100).iterrows():
    folium.CircleMarker(
        location=[row['YCOORD'], row['XCOORD']],
        radius=2,
        fill=True,
        fill_color="red",
        color="red",
        opacity=0.6,
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0857c035a148ab1ed53e45ea5f412a85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0857c035a148ab1ed53e45ea5f412a85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0857c035a148ab1ed53e45ea5f412a85 = L.map(
#                 &quot;map_0857c035a148ab1ed53e45ea5f412a85&quot;,
#                 {
#                     center: [40.44, -79.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e31e5637ea340f63d23956986c0feb01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e31e5637ea340f63d23956986c0feb01.addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_6b63f5ba4fc8cb0b11eed3f3d3bd116d = L.circleMarker(
#                 [40.4187, -79.9944],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_f9fddc7a67c6116bf9292c521dfab04b = L.circleMarker(
#                 [40.4533, -80.0475],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_2efab7b3280eaa8415d4b1b23c34862f = L.circleMarker(
#                 [40.4582, -79.9349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_194a2483693c73cee61195ca45d74182 = L.circleMarker(
#                 [40.4636, -79.9669],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_2aef048865d862924089d8c8e56b1e2c = L.circleMarker(
#                 [40.4114, -79.9904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0857c035a148ab1ed53e45ea5f412a85);
#
#
#             var circle_marker_8bdb895f8927cd67c10edeab053c751c = L.circleMarker(
#                 [40.4438, -79.9141],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.6, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
